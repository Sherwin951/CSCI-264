# %%
import numpy as np

# %%
# Sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# Derivative of sigmoid function
def sigmoid_prime(x):
    return sigmoid(x) * (1 - sigmoid(x))

# %%
# Initialize a neural network
def initialize_network(input_size, hidden_size, output_size):
    network = {
        'weights_input_hidden': np.random.rand(hidden_size, input_size) * 0.02 - 0.01,
        'weights_hidden_output': np.random.rand(output_size, hidden_size) * 0.02 - 0.01
    }
    return network

# %%
# Forward propagate an input
def forward_propagate(network, input_data):
    hidden_output = sigmoid(np.dot(network['weights_input_hidden'], input_data))
    output = sigmoid(np.dot(network['weights_hidden_output'], hidden_output))
    return output

# %%
# Back propagate error and update weights
def backpropagate(network, input_data, target_output, learning_rate):
    hidden_output = sigmoid(np.dot(network['weights_input_hidden'], input_data))
    output = sigmoid(np.dot(network['weights_hidden_output'], hidden_output))

    output_error = target_output - output
    hidden_error = np.dot(network['weights_hidden_output'].T, output_error)

    delta_output = output_error * sigmoid_prime(output)
    delta_hidden = hidden_error * sigmoid_prime(hidden_output)

    network['weights_hidden_output'] += learning_rate * np.outer(delta_output, hidden_output)
    network['weights_input_hidden'] += learning_rate * np.outer(delta_hidden, input_data)

# %%
# Train the network with online training
def train_network_online(network, input_data, target_output, learning_rate, epochs):
    errors = []
    accuracies = []
    for epoch in range(epochs):
        total_squared_error = 0
        correct_predictions = 0
        for i in range(len(input_data)):
            backpropagate(network, input_data[i], target_output[i], learning_rate)
            prediction = forward_propagate(network, input_data[i])[0]
            total_squared_error += (target_output[i] - prediction) ** 2
            if round(prediction) == target_output[i]:
                correct_predictions += 1
        errors.append(total_squared_error)
        accuracies.append(correct_predictions / len(input_data))
        print(f"Epoch {epoch+1}: Error = {total_squared_error}, Accuracy = {accuracies[-1]}")
    return errors, accuracies

# %%
# Train the network with batch training
def train_network_batch(network, input_data, target_output, learning_rate, epochs):
    errors = []
    accuracies = []
    for epoch in range(epochs):
        total_squared_error = 0
        correct_predictions = 0
        delta_output_batch = np.zeros_like(network['weights_hidden_output'])
        delta_hidden_batch = np.zeros_like(network['weights_input_hidden'])
        for i in range(len(input_data)):
            hidden_output = sigmoid(np.dot(network['weights_input_hidden'], input_data[i]))
            output = sigmoid(np.dot(network['weights_hidden_output'], hidden_output))
            output_error = target_output[i] - output
            hidden_error = np.dot(network['weights_hidden_output'].T, output_error)
            delta_output = output_error * sigmoid_prime(output)
            delta_hidden = hidden_error * sigmoid_prime(hidden_output)
            delta_output_batch += np.outer(delta_output, hidden_output)
            delta_hidden_batch += np.outer(delta_hidden, input_data[i])
            prediction = output[0]
            total_squared_error += (target_output[i] - prediction) ** 2
            if round(prediction) == target_output[i]:
                correct_predictions += 1
        network['weights_hidden_output'] += learning_rate * delta_output_batch / len(input_data)
        network['weights_input_hidden'] += learning_rate * delta_hidden_batch / len(input_data)
        errors.append(total_squared_error)
        accuracies.append(correct_predictions / len(input_data))
        print(f"Epoch {epoch+1}: Error = {total_squared_error}, Accuracy = {accuracies[-1]}")
    return errors, accuracies

# %%
# Example usage
input_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
target_output = np.array([[0], [1], [1], [0]])

# Learning Experiment with Online Training
print("Learning Experiment with Online Training:")
for i in range(5):
    print(f"\nExperiment {i+1}:")
    network = initialize_network(input_size=2, hidden_size=4, output_size=1)
    print("Initial Random Weights:")
    print("weights_input_hidden:", network['weights_input_hidden'])
    print("weights_hidden_output:", network['weights_hidden_output'])
    errors, accuracies = train_network_online(network, input_data, target_output, learning_rate=0.1, epochs=50)
    print("Final Weights:")
    print("weights_input_hidden:", network['weights_input_hidden'])
    print("weights_hidden_output:", network['weights_hidden_output'])
    print("Squared Error at the end of training:", errors[-1])
    print("Accuracy at the end of training:", accuracies[-1])
# Out:
# Learning Experiment with Online Training:
#
# Experiment 1:
# Initial Random Weights:
# weights_input_hidden: [[ 6.47933970e-03 -2.66359250e-03]
#  [-8.55936452e-03  5.77122411e-04]
#  [ 8.92823277e-05  4.36224938e-03]
#  [ 3.11877751e-03  5.64730623e-03]]
# weights_hidden_output: [[-0.00343798 -0.00525354  0.00032469 -0.00681902]]
# Epoch 1: Error = [0.99411248], Accuracy = 0.75
# Epoch 2: Error = [0.99411246], Accuracy = 0.75
# Epoch 3: Error = [0.99411247], Accuracy = 0.75
# Epoch 4: Error = [0.99411252], Accuracy = 0.75
# Epoch 5: Error = [0.99411259], Accuracy = 0.75
# Epoch 6: Error = [0.9941127], Accuracy = 0.75
# Epoch 7: Error = [0.99411283], Accuracy = 0.75
# Epoch 8: Error = [0.99411298], Accuracy = 0.75
# Epoch 9: Error = [0.99411316], Accuracy = 0.75
# Epoch 10: Error = [0.99411336], Accuracy = 0.75
# Epoch 11: Error = [0.99411359], Accuracy = 0.75
# Epoch 12: Error = [0.99411383], Accuracy = 0.75
# Epoch 13: Error = [0.99411409], Accuracy = 0.75
# Epoch 14: Error = [0.99411438], Accuracy = 0.75
# Epoch 15: Error = [0.99411468], Accuracy = 0.75
# Epoch 16: Error = [0.99411499], Accuracy = 0.75
# Epoch 17: Error = [0.99411533], Accuracy = 0.75
# Epoch 18: Error = [0.99411568], Accuracy = 0.75
# Epoch 19: Error = [0.99411604], Accuracy = 0.75
# Epoch 20: Error = [0.99411642], Accuracy = 0.75
# Epoch 21: Error = [0.99411681], Accuracy = 0.75
# Epoch 22: Error = [0.99411721], Accuracy = 0.75
# Epoch 23: Error = [0.99411763], Accuracy = 0.75
# Epoch 24: Error = [0.99411805], Accuracy = 0.75
# Epoch 25: Error = [0.99411849], Accuracy = 0.75
# Epoch 26: Error = [0.99411893], Accuracy = 0.75
# Epoch 27: Error = [0.99411939], Accuracy = 0.75
# Epoch 28: Error = [0.99411986], Accuracy = 0.75
# Epoch 29: Error = [0.99412033], Accuracy = 0.75
# Epoch 30: Error = [0.99412081], Accuracy = 0.75
# Epoch 31: Error = [0.9941213], Accuracy = 0.75
# Epoch 32: Error = [0.9941218], Accuracy = 0.75
# Epoch 33: Error = [0.9941223], Accuracy = 0.75
# Epoch 34: Error = [0.99412281], Accuracy = 0.75
# Epoch 35: Error = [0.99412333], Accuracy = 0.75
# Epoch 36: Error = [0.99412386], Accuracy = 0.75
# Epoch 37: Error = [0.99412438], Accuracy = 0.75
# Epoch 38: Error = [0.99412492], Accuracy = 0.75
# Epoch 39: Error = [0.99412546], Accuracy = 0.75
# Epoch 40: Error = [0.994126], Accuracy = 0.75
# Epoch 41: Error = [0.99412655], Accuracy = 0.75
# Epoch 42: Error = [0.9941271], Accuracy = 0.75
# Epoch 43: Error = [0.99412766], Accuracy = 0.75
# Epoch 44: Error = [0.99412822], Accuracy = 0.75
# Epoch 45: Error = [0.99412879], Accuracy = 0.75
# Epoch 46: Error = [0.99412936], Accuracy = 0.75
# Epoch 47: Error = [0.99412993], Accuracy = 0.75
# Epoch 48: Error = [0.9941305], Accuracy = 0.75
# Epoch 49: Error = [0.99413108], Accuracy = 0.75
# Epoch 50: Error = [0.99413166], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[ 0.00299924 -0.00965122]
#  [-0.01201399 -0.00639469]
#  [-0.00338384 -0.0026156 ]
#  [-0.00035172 -0.00135433]]
# weights_hidden_output: [[-0.00056466 -0.00236895  0.00319165 -0.00392667]]
# Squared Error at the end of training: [0.99413166]
# Accuracy at the end of training: 0.75
#
# Experiment 2:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00482167 -0.00443379]
#  [-0.00849631 -0.00724677]
#  [-0.00744863 -0.00239426]
#  [-0.00845231  0.00302617]]
# weights_hidden_output: [[ 0.00261105  0.00296144 -0.00249523 -0.00816862]]
# Epoch 1: Error = [0.99413104], Accuracy = 0.75
# Epoch 2: Error = [0.99413159], Accuracy = 0.75
# Epoch 3: Error = [0.99413214], Accuracy = 0.75
# Epoch 4: Error = [0.9941327], Accuracy = 0.75
# Epoch 5: Error = [0.99413326], Accuracy = 0.75
# Epoch 6: Error = [0.99413383], Accuracy = 0.75
# Epoch 7: Error = [0.9941344], Accuracy = 0.75
# Epoch 8: Error = [0.99413497], Accuracy = 0.75
# Epoch 9: Error = [0.99413555], Accuracy = 0.75
# Epoch 10: Error = [0.99413613], Accuracy = 0.75
# Epoch 11: Error = [0.99413671], Accuracy = 0.75
# Epoch 12: Error = [0.99413729], Accuracy = 0.75
# Epoch 13: Error = [0.99413788], Accuracy = 0.75
# Epoch 14: Error = [0.99413846], Accuracy = 0.75
# Epoch 15: Error = [0.99413905], Accuracy = 0.75
# Epoch 16: Error = [0.99413965], Accuracy = 0.75
# Epoch 17: Error = [0.99414024], Accuracy = 0.75
# Epoch 18: Error = [0.99414084], Accuracy = 0.75
# Epoch 19: Error = [0.99414143], Accuracy = 0.75
# Epoch 20: Error = [0.99414203], Accuracy = 0.75
# Epoch 21: Error = [0.99414263], Accuracy = 0.75
# Epoch 22: Error = [0.99414324], Accuracy = 0.75
# Epoch 23: Error = [0.99414384], Accuracy = 0.75
# Epoch 24: Error = [0.99414444], Accuracy = 0.75
# Epoch 25: Error = [0.99414505], Accuracy = 0.75
# Epoch 26: Error = [0.99414566], Accuracy = 0.75
# Epoch 27: Error = [0.99414626], Accuracy = 0.75
# Epoch 28: Error = [0.99414687], Accuracy = 0.75
# Epoch 29: Error = [0.99414748], Accuracy = 0.75
# Epoch 30: Error = [0.99414809], Accuracy = 0.75
# Epoch 31: Error = [0.9941487], Accuracy = 0.75
# Epoch 32: Error = [0.99414932], Accuracy = 0.75
# Epoch 33: Error = [0.99414993], Accuracy = 0.75
# Epoch 34: Error = [0.99415054], Accuracy = 0.75
# Epoch 35: Error = [0.99415116], Accuracy = 0.75
# Epoch 36: Error = [0.99415177], Accuracy = 0.75
# Epoch 37: Error = [0.99415238], Accuracy = 0.75
# Epoch 38: Error = [0.994153], Accuracy = 0.75
# Epoch 39: Error = [0.99415362], Accuracy = 0.75
# Epoch 40: Error = [0.99415423], Accuracy = 0.75
# Epoch 41: Error = [0.99415485], Accuracy = 0.75
# Epoch 42: Error = [0.99415546], Accuracy = 0.75
# Epoch 43: Error = [0.99415608], Accuracy = 0.75
# Epoch 44: Error = [0.9941567], Accuracy = 0.75
# Epoch 45: Error = [0.99415732], Accuracy = 0.75
# Epoch 46: Error = [0.99415793], Accuracy = 0.75
# Epoch 47: Error = [0.99415855], Accuracy = 0.75
# Epoch 48: Error = [0.99415917], Accuracy = 0.75
# Epoch 49: Error = [0.99415979], Accuracy = 0.75
# Epoch 50: Error = [0.99416041], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[ 0.00133316 -0.01139675]
#  [-0.01196651 -0.01418715]
#  [-0.01090276 -0.00934469]
#  [-0.0118885  -0.00393182]]
# weights_hidden_output: [[ 0.00373195  0.00408767 -0.00134873 -0.00699971]]
# Squared Error at the end of training: [0.99416041]
# Accuracy at the end of training: 0.75
#
# Experiment 3:
# Initial Random Weights:
# weights_input_hidden: [[ 5.52159355e-03 -5.99771213e-03]
#  [ 5.64047246e-03  7.10065757e-03]
#  [-5.64408245e-03 -6.87322615e-05]
#  [-6.23927180e-03 -4.68198974e-03]]
# weights_hidden_output: [[-0.00844556 -0.00203995  0.00182938 -0.00189679]]
# Epoch 1: Error = [0.99411594], Accuracy = 0.75
# Epoch 2: Error = [0.99411626], Accuracy = 0.75
# Epoch 3: Error = [0.99411659], Accuracy = 0.75
# Epoch 4: Error = [0.99411694], Accuracy = 0.75
# Epoch 5: Error = [0.9941173], Accuracy = 0.75
# Epoch 6: Error = [0.99411767], Accuracy = 0.75
# Epoch 7: Error = [0.99411806], Accuracy = 0.75
# Epoch 8: Error = [0.99411846], Accuracy = 0.75
# Epoch 9: Error = [0.99411887], Accuracy = 0.75
# Epoch 10: Error = [0.9941193], Accuracy = 0.75
# Epoch 11: Error = [0.99411973], Accuracy = 0.75
# Epoch 12: Error = [0.99412017], Accuracy = 0.75
# Epoch 13: Error = [0.99412063], Accuracy = 0.75
# Epoch 14: Error = [0.99412109], Accuracy = 0.75
# Epoch 15: Error = [0.99412157], Accuracy = 0.75
# Epoch 16: Error = [0.99412205], Accuracy = 0.75
# Epoch 17: Error = [0.99412253], Accuracy = 0.75
# Epoch 18: Error = [0.99412303], Accuracy = 0.75
# Epoch 19: Error = [0.99412353], Accuracy = 0.75
# Epoch 20: Error = [0.99412404], Accuracy = 0.75
# Epoch 21: Error = [0.99412456], Accuracy = 0.75
# Epoch 22: Error = [0.99412508], Accuracy = 0.75
# Epoch 23: Error = [0.99412561], Accuracy = 0.75
# Epoch 24: Error = [0.99412614], Accuracy = 0.75
# Epoch 25: Error = [0.99412668], Accuracy = 0.75
# Epoch 26: Error = [0.99412722], Accuracy = 0.75
# Epoch 27: Error = [0.99412777], Accuracy = 0.75
# Epoch 28: Error = [0.99412832], Accuracy = 0.75
# Epoch 29: Error = [0.99412888], Accuracy = 0.75
# Epoch 30: Error = [0.99412944], Accuracy = 0.75
# Epoch 31: Error = [0.99413], Accuracy = 0.75
# Epoch 32: Error = [0.99413057], Accuracy = 0.75
# Epoch 33: Error = [0.99413114], Accuracy = 0.75
# Epoch 34: Error = [0.99413172], Accuracy = 0.75
# Epoch 35: Error = [0.99413229], Accuracy = 0.75
# Epoch 36: Error = [0.99413287], Accuracy = 0.75
# Epoch 37: Error = [0.99413345], Accuracy = 0.75
# Epoch 38: Error = [0.99413404], Accuracy = 0.75
# Epoch 39: Error = [0.99413463], Accuracy = 0.75
# Epoch 40: Error = [0.99413522], Accuracy = 0.75
# Epoch 41: Error = [0.99413581], Accuracy = 0.75
# Epoch 42: Error = [0.9941364], Accuracy = 0.75
# Epoch 43: Error = [0.994137], Accuracy = 0.75
# Epoch 44: Error = [0.99413759], Accuracy = 0.75
# Epoch 45: Error = [0.99413819], Accuracy = 0.75
# Epoch 46: Error = [0.99413879], Accuracy = 0.75
# Epoch 47: Error = [0.99413939], Accuracy = 0.75
# Epoch 48: Error = [0.99414], Accuracy = 0.75
# Epoch 49: Error = [0.9941406], Accuracy = 0.75
# Epoch 50: Error = [0.9941412], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[ 0.00205634 -0.01298189]
#  [ 0.00216354  0.00011034]
#  [-0.0091126  -0.00702678]
#  [-0.00970049 -0.01163813]]
# weights_hidden_output: [[-6.35101507e-03  4.03456207e-05  3.89575127e-03  1.79871404e-04]]
# Squared Error at the end of training: [0.9941412]
# Accuracy at the end of training: 0.75
#
# Experiment 4:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00727026 -0.00938122]
#  [ 0.004832   -0.00727928]
#  [ 0.0036598  -0.00178673]
#  [ 0.00011977 -0.00992051]]
# weights_hidden_output: [[-0.00172256 -0.00645799 -0.0020144  -0.00301853]]
# Epoch 1: Error = [0.99412555], Accuracy = 0.75
# Epoch 2: Error = [0.99412569], Accuracy = 0.75
# Epoch 3: Error = [0.99412585], Accuracy = 0.75
# Epoch 4: Error = [0.99412604], Accuracy = 0.75
# Epoch 5: Error = [0.99412625], Accuracy = 0.75
# Epoch 6: Error = [0.99412648], Accuracy = 0.75
# Epoch 7: Error = [0.99412673], Accuracy = 0.75
# Epoch 8: Error = [0.994127], Accuracy = 0.75
# Epoch 9: Error = [0.99412729], Accuracy = 0.75
# Epoch 10: Error = [0.9941276], Accuracy = 0.75
# Epoch 11: Error = [0.99412792], Accuracy = 0.75
# Epoch 12: Error = [0.99412826], Accuracy = 0.75
# Epoch 13: Error = [0.99412861], Accuracy = 0.75
# Epoch 14: Error = [0.99412898], Accuracy = 0.75
# Epoch 15: Error = [0.99412936], Accuracy = 0.75
# Epoch 16: Error = [0.99412975], Accuracy = 0.75
# Epoch 17: Error = [0.99413016], Accuracy = 0.75
# Epoch 18: Error = [0.99413058], Accuracy = 0.75
# Epoch 19: Error = [0.99413101], Accuracy = 0.75
# Epoch 20: Error = [0.99413144], Accuracy = 0.75
# Epoch 21: Error = [0.99413189], Accuracy = 0.75
# Epoch 22: Error = [0.99413235], Accuracy = 0.75
# Epoch 23: Error = [0.99413282], Accuracy = 0.75
# Epoch 24: Error = [0.9941333], Accuracy = 0.75
# Epoch 25: Error = [0.99413378], Accuracy = 0.75
# Epoch 26: Error = [0.99413427], Accuracy = 0.75
# Epoch 27: Error = [0.99413477], Accuracy = 0.75
# Epoch 28: Error = [0.99413527], Accuracy = 0.75
# Epoch 29: Error = [0.99413579], Accuracy = 0.75
# Epoch 30: Error = [0.9941363], Accuracy = 0.75
# Epoch 31: Error = [0.99413683], Accuracy = 0.75
# Epoch 32: Error = [0.99413736], Accuracy = 0.75
# Epoch 33: Error = [0.99413789], Accuracy = 0.75
# Epoch 34: Error = [0.99413843], Accuracy = 0.75
# Epoch 35: Error = [0.99413898], Accuracy = 0.75
# Epoch 36: Error = [0.99413953], Accuracy = 0.75
# Epoch 37: Error = [0.99414008], Accuracy = 0.75
# Epoch 38: Error = [0.99414064], Accuracy = 0.75
# Epoch 39: Error = [0.9941412], Accuracy = 0.75
# Epoch 40: Error = [0.99414176], Accuracy = 0.75
# Epoch 41: Error = [0.99414233], Accuracy = 0.75
# Epoch 42: Error = [0.9941429], Accuracy = 0.75
# Epoch 43: Error = [0.99414348], Accuracy = 0.75
# Epoch 44: Error = [0.99414405], Accuracy = 0.75
# Epoch 45: Error = [0.99414463], Accuracy = 0.75
# Epoch 46: Error = [0.99414522], Accuracy = 0.75
# Epoch 47: Error = [0.9941458], Accuracy = 0.75
# Epoch 48: Error = [0.99414639], Accuracy = 0.75
# Epoch 49: Error = [0.99414698], Accuracy = 0.75
# Epoch 50: Error = [0.99414757], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[ 0.00378604 -0.01635449]
#  [ 0.00136012 -0.01426201]
#  [ 0.00018305 -0.00876515]
#  [-0.00335129 -0.01688475]]
# weights_hidden_output: [[ 0.00080649 -0.00391041  0.000522   -0.00048375]]
# Squared Error at the end of training: [0.99414757]
# Accuracy at the end of training: 0.75
#
# Experiment 5:
# Initial Random Weights:
# weights_input_hidden: [[ 0.0079012   0.0010435 ]
#  [ 0.00685287  0.00697568]
#  [-0.00615732  0.00819956]
#  [ 0.0048976  -0.00154814]]
# weights_hidden_output: [[-0.00038862  0.00418358 -0.00585643  0.00992319]]
# Epoch 1: Error = [0.99409182], Accuracy = 0.75
# Epoch 2: Error = [0.99409227], Accuracy = 0.75
# Epoch 3: Error = [0.99409273], Accuracy = 0.75
# Epoch 4: Error = [0.99409319], Accuracy = 0.75
# Epoch 5: Error = [0.99409366], Accuracy = 0.75
# Epoch 6: Error = [0.99409414], Accuracy = 0.75
# Epoch 7: Error = [0.99409462], Accuracy = 0.75
# Epoch 8: Error = [0.99409511], Accuracy = 0.75
# Epoch 9: Error = [0.9940956], Accuracy = 0.75
# Epoch 10: Error = [0.9940961], Accuracy = 0.75
# Epoch 11: Error = [0.9940966], Accuracy = 0.75
# Epoch 12: Error = [0.99409711], Accuracy = 0.75
# Epoch 13: Error = [0.99409762], Accuracy = 0.75
# Epoch 14: Error = [0.99409814], Accuracy = 0.75
# Epoch 15: Error = [0.99409865], Accuracy = 0.75
# Epoch 16: Error = [0.99409918], Accuracy = 0.75
# Epoch 17: Error = [0.9940997], Accuracy = 0.75
# Epoch 18: Error = [0.99410024], Accuracy = 0.75
# Epoch 19: Error = [0.99410077], Accuracy = 0.75
# Epoch 20: Error = [0.99410131], Accuracy = 0.75
# Epoch 21: Error = [0.99410185], Accuracy = 0.75
# Epoch 22: Error = [0.99410239], Accuracy = 0.75
# Epoch 23: Error = [0.99410293], Accuracy = 0.75
# Epoch 24: Error = [0.99410348], Accuracy = 0.75
# Epoch 25: Error = [0.99410403], Accuracy = 0.75
# Epoch 26: Error = [0.99410459], Accuracy = 0.75
# Epoch 27: Error = [0.99410514], Accuracy = 0.75
# Epoch 28: Error = [0.9941057], Accuracy = 0.75
# Epoch 29: Error = [0.99410626], Accuracy = 0.75
# Epoch 30: Error = [0.99410683], Accuracy = 0.75
# Epoch 31: Error = [0.99410739], Accuracy = 0.75
# Epoch 32: Error = [0.99410796], Accuracy = 0.75
# Epoch 33: Error = [0.99410852], Accuracy = 0.75
# Epoch 34: Error = [0.9941091], Accuracy = 0.75
# Epoch 35: Error = [0.99410967], Accuracy = 0.75
# Epoch 36: Error = [0.99411024], Accuracy = 0.75
# Epoch 37: Error = [0.99411082], Accuracy = 0.75
# Epoch 38: Error = [0.99411139], Accuracy = 0.75
# Epoch 39: Error = [0.99411197], Accuracy = 0.75
# Epoch 40: Error = [0.99411255], Accuracy = 0.75
# Epoch 41: Error = [0.99411313], Accuracy = 0.75
# Epoch 42: Error = [0.99411371], Accuracy = 0.75
# Epoch 43: Error = [0.9941143], Accuracy = 0.75
# Epoch 44: Error = [0.99411488], Accuracy = 0.75
# Epoch 45: Error = [0.99411547], Accuracy = 0.75
# Epoch 46: Error = [0.99411605], Accuracy = 0.75
# Epoch 47: Error = [0.99411664], Accuracy = 0.75
# Epoch 48: Error = [0.99411723], Accuracy = 0.75
# Epoch 49: Error = [0.99411782], Accuracy = 0.75
# Epoch 50: Error = [0.99411841], Accuracy = 0.75
# Final Weights:
# weights_input_hidden: [[ 4.42507706e-03 -5.91824615e-03]
#  [ 3.35699008e-03  1.58327944e-06]
#  [-9.58442535e-03  1.26022224e-03]
#  [ 1.37217959e-03 -8.51635831e-03]]
# weights_hidden_output: [[-0.00150565  0.00305084 -0.00693964  0.00877427]]
# Squared Error at the end of training: [0.99411841]
# Accuracy at the end of training: 0.75

# %%
# Learning Experiment with Batch Training
print("\nLearning Experiment with Batch Training:")
for i in range(5):
    print(f"\nExperiment {i+1}:")
    network = initialize_network(input_size=2, hidden_size=4, output_size=1)
    print("Initial Random Weights:")
    print("weights_input_hidden:", network['weights_input_hidden'])
    print("weights_hidden_output:", network['weights_hidden_output'])
    errors, accuracies = train_network_batch(network, input_data, target_output, learning_rate=0.1, epochs=50)
    print("Final Weights:")
    print("weights_input_hidden:", network['weights_input_hidden'])
    print("weights_hidden_output:", network['weights_hidden_output'])
    print("Squared Error at the end of training:", errors[-1])
    print("Accuracy at the end of training:", accuracies[-1])
# Out:
# Learning Experiment with Batch Training:
#
# Experiment 1:
# Initial Random Weights:
# weights_input_hidden: [[-0.00402368  0.00078788]
#  [ 0.00706512  0.00165636]
#  [ 0.00083508 -0.00713706]
#  [ 0.00940393  0.00153265]]
# weights_hidden_output: [[ 0.00528321  0.00817163 -0.00110824  0.0014585 ]]
# Epoch 1: Error = [1.00001194], Accuracy = 0.5
# Epoch 2: Error = [1.0000118], Accuracy = 0.5
# Epoch 3: Error = [1.00001167], Accuracy = 0.5
# Epoch 4: Error = [1.00001153], Accuracy = 0.5
# Epoch 5: Error = [1.00001139], Accuracy = 0.5
# Epoch 6: Error = [1.00001126], Accuracy = 0.5
# Epoch 7: Error = [1.00001113], Accuracy = 0.5
# Epoch 8: Error = [1.000011], Accuracy = 0.5
# Epoch 9: Error = [1.00001087], Accuracy = 0.5
# Epoch 10: Error = [1.00001074], Accuracy = 0.5
# Epoch 11: Error = [1.00001062], Accuracy = 0.5
# Epoch 12: Error = [1.00001049], Accuracy = 0.5
# Epoch 13: Error = [1.00001037], Accuracy = 0.5
# Epoch 14: Error = [1.00001025], Accuracy = 0.5
# Epoch 15: Error = [1.00001013], Accuracy = 0.5
# Epoch 16: Error = [1.00001001], Accuracy = 0.5
# Epoch 17: Error = [1.00000989], Accuracy = 0.5
# Epoch 18: Error = [1.00000977], Accuracy = 0.5
# Epoch 19: Error = [1.00000966], Accuracy = 0.5
# Epoch 20: Error = [1.00000955], Accuracy = 0.5
# Epoch 21: Error = [1.00000943], Accuracy = 0.5
# Epoch 22: Error = [1.00000932], Accuracy = 0.5
# Epoch 23: Error = [1.00000921], Accuracy = 0.5
# Epoch 24: Error = [1.00000911], Accuracy = 0.5
# Epoch 25: Error = [1.000009], Accuracy = 0.5
# Epoch 26: Error = [1.00000889], Accuracy = 0.5
# Epoch 27: Error = [1.00000879], Accuracy = 0.5
# Epoch 28: Error = [1.00000869], Accuracy = 0.5
# Epoch 29: Error = [1.00000858], Accuracy = 0.5
# Epoch 30: Error = [1.00000848], Accuracy = 0.5
# Epoch 31: Error = [1.00000838], Accuracy = 0.5
# Epoch 32: Error = [1.00000829], Accuracy = 0.5
# Epoch 33: Error = [1.00000819], Accuracy = 0.5
# Epoch 34: Error = [1.00000809], Accuracy = 0.5
# Epoch 35: Error = [1.000008], Accuracy = 0.5
# Epoch 36: Error = [1.0000079], Accuracy = 0.5
# Epoch 37: Error = [1.00000781], Accuracy = 0.5
# Epoch 38: Error = [1.00000772], Accuracy = 0.5
# Epoch 39: Error = [1.00000763], Accuracy = 0.5
# Epoch 40: Error = [1.00000754], Accuracy = 0.5
# Epoch 41: Error = [1.00000745], Accuracy = 0.5
# Epoch 42: Error = [1.00000736], Accuracy = 0.5
# Epoch 43: Error = [1.00000728], Accuracy = 0.5
# Epoch 44: Error = [1.00000719], Accuracy = 0.5
# Epoch 45: Error = [1.00000711], Accuracy = 0.5
# Epoch 46: Error = [1.00000703], Accuracy = 0.5
# Epoch 47: Error = [1.00000694], Accuracy = 0.5
# Epoch 48: Error = [1.00000686], Accuracy = 0.5
# Epoch 49: Error = [1.00000678], Accuracy = 0.5
# Epoch 50: Error = [1.0000067], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[-0.00402793  0.00078343]
#  [ 0.0070584   0.00165002]
#  [ 0.00083653 -0.00713572]
#  [ 0.00940304  0.00153183]]
# weights_hidden_output: [[ 0.00440242  0.0072882  -0.00198836  0.00057457]]
# Squared Error at the end of training: [1.0000067]
# Accuracy at the end of training: 0.5
#
# Experiment 2:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00171898 -0.00067519]
#  [ 0.00265265 -0.00640572]
#  [ 0.003578   -0.00650088]
#  [-0.00256939  0.00541483]]
# weights_hidden_output: [[0.00869422 0.00035967 0.00585875 0.00884196]]
# Epoch 1: Error = [1.00003528], Accuracy = 0.5
# Epoch 2: Error = [1.00003487], Accuracy = 0.5
# Epoch 3: Error = [1.00003446], Accuracy = 0.5
# Epoch 4: Error = [1.00003405], Accuracy = 0.5
# Epoch 5: Error = [1.00003366], Accuracy = 0.5
# Epoch 6: Error = [1.00003326], Accuracy = 0.5
# Epoch 7: Error = [1.00003287], Accuracy = 0.5
# Epoch 8: Error = [1.00003249], Accuracy = 0.5
# Epoch 9: Error = [1.00003211], Accuracy = 0.5
# Epoch 10: Error = [1.00003173], Accuracy = 0.5
# Epoch 11: Error = [1.00003136], Accuracy = 0.5
# Epoch 12: Error = [1.00003099], Accuracy = 0.5
# Epoch 13: Error = [1.00003063], Accuracy = 0.5
# Epoch 14: Error = [1.00003027], Accuracy = 0.5
# Epoch 15: Error = [1.00002992], Accuracy = 0.5
# Epoch 16: Error = [1.00002957], Accuracy = 0.5
# Epoch 17: Error = [1.00002922], Accuracy = 0.5
# Epoch 18: Error = [1.00002888], Accuracy = 0.5
# Epoch 19: Error = [1.00002854], Accuracy = 0.5
# Epoch 20: Error = [1.00002821], Accuracy = 0.5
# Epoch 21: Error = [1.00002788], Accuracy = 0.5
# Epoch 22: Error = [1.00002755], Accuracy = 0.5
# Epoch 23: Error = [1.00002723], Accuracy = 0.5
# Epoch 24: Error = [1.00002691], Accuracy = 0.5
# Epoch 25: Error = [1.0000266], Accuracy = 0.5
# Epoch 26: Error = [1.00002628], Accuracy = 0.5
# Epoch 27: Error = [1.00002598], Accuracy = 0.5
# Epoch 28: Error = [1.00002567], Accuracy = 0.5
# Epoch 29: Error = [1.00002537], Accuracy = 0.5
# Epoch 30: Error = [1.00002507], Accuracy = 0.5
# Epoch 31: Error = [1.00002478], Accuracy = 0.5
# Epoch 32: Error = [1.00002449], Accuracy = 0.5
# Epoch 33: Error = [1.0000242], Accuracy = 0.5
# Epoch 34: Error = [1.00002392], Accuracy = 0.5
# Epoch 35: Error = [1.00002364], Accuracy = 0.5
# Epoch 36: Error = [1.00002336], Accuracy = 0.5
# Epoch 37: Error = [1.00002309], Accuracy = 0.5
# Epoch 38: Error = [1.00002282], Accuracy = 0.5
# Epoch 39: Error = [1.00002255], Accuracy = 0.5
# Epoch 40: Error = [1.00002229], Accuracy = 0.5
# Epoch 41: Error = [1.00002203], Accuracy = 0.5
# Epoch 42: Error = [1.00002177], Accuracy = 0.5
# Epoch 43: Error = [1.00002152], Accuracy = 0.5
# Epoch 44: Error = [1.00002126], Accuracy = 0.5
# Epoch 45: Error = [1.00002102], Accuracy = 0.5
# Epoch 46: Error = [1.00002077], Accuracy = 0.5
# Epoch 47: Error = [1.00002053], Accuracy = 0.5
# Epoch 48: Error = [1.00002029], Accuracy = 0.5
# Epoch 49: Error = [1.00002005], Accuracy = 0.5
# Epoch 50: Error = [1.00001981], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[ 0.00170688 -0.00068712]
#  [ 0.00265325 -0.00640515]
#  [ 0.00356994 -0.00650847]
#  [-0.00258128  0.00540237]]
# weights_hidden_output: [[ 0.00717888 -0.00115385  0.00434492  0.00732595]]
# Squared Error at the end of training: [1.00001981]
# Accuracy at the end of training: 0.5
#
# Experiment 3:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00281642 -0.00216162]
#  [ 0.00691384 -0.00908812]
#  [ 0.00228523  0.00053762]
#  [ 0.00041499 -0.00775668]]
# weights_hidden_output: [[ 0.00309253  0.00048387 -0.0084112  -0.00471001]]
# Epoch 1: Error = [1.00000569], Accuracy = 0.5
# Epoch 2: Error = [1.00000562], Accuracy = 0.5
# Epoch 3: Error = [1.00000556], Accuracy = 0.5
# Epoch 4: Error = [1.00000549], Accuracy = 0.5
# Epoch 5: Error = [1.00000543], Accuracy = 0.5
# Epoch 6: Error = [1.00000536], Accuracy = 0.5
# Epoch 7: Error = [1.0000053], Accuracy = 0.5
# Epoch 8: Error = [1.00000524], Accuracy = 0.5
# Epoch 9: Error = [1.00000518], Accuracy = 0.5
# Epoch 10: Error = [1.00000512], Accuracy = 0.5
# Epoch 11: Error = [1.00000506], Accuracy = 0.5
# Epoch 12: Error = [1.000005], Accuracy = 0.5
# Epoch 13: Error = [1.00000494], Accuracy = 0.5
# Epoch 14: Error = [1.00000488], Accuracy = 0.5
# Epoch 15: Error = [1.00000483], Accuracy = 0.5
# Epoch 16: Error = [1.00000477], Accuracy = 0.5
# Epoch 17: Error = [1.00000471], Accuracy = 0.5
# Epoch 18: Error = [1.00000466], Accuracy = 0.5
# Epoch 19: Error = [1.0000046], Accuracy = 0.5
# Epoch 20: Error = [1.00000455], Accuracy = 0.5
# Epoch 21: Error = [1.0000045], Accuracy = 0.5
# Epoch 22: Error = [1.00000444], Accuracy = 0.5
# Epoch 23: Error = [1.00000439], Accuracy = 0.5
# Epoch 24: Error = [1.00000434], Accuracy = 0.5
# Epoch 25: Error = [1.00000429], Accuracy = 0.5
# Epoch 26: Error = [1.00000424], Accuracy = 0.5
# Epoch 27: Error = [1.00000419], Accuracy = 0.5
# Epoch 28: Error = [1.00000414], Accuracy = 0.5
# Epoch 29: Error = [1.00000409], Accuracy = 0.5
# Epoch 30: Error = [1.00000404], Accuracy = 0.5
# Epoch 31: Error = [1.000004], Accuracy = 0.5
# Epoch 32: Error = [1.00000395], Accuracy = 0.5
# Epoch 33: Error = [1.0000039], Accuracy = 0.5
# Epoch 34: Error = [1.00000386], Accuracy = 0.5
# Epoch 35: Error = [1.00000381], Accuracy = 0.5
# Epoch 36: Error = [1.00000377], Accuracy = 0.5
# Epoch 37: Error = [1.00000372], Accuracy = 0.5
# Epoch 38: Error = [1.00000368], Accuracy = 0.5
# Epoch 39: Error = [1.00000364], Accuracy = 0.5
# Epoch 40: Error = [1.00000359], Accuracy = 0.5
# Epoch 41: Error = [1.00000355], Accuracy = 0.5
# Epoch 42: Error = [1.00000351], Accuracy = 0.5
# Epoch 43: Error = [1.00000347], Accuracy = 0.5
# Epoch 44: Error = [1.00000343], Accuracy = 0.5
# Epoch 45: Error = [1.00000339], Accuracy = 0.5
# Epoch 46: Error = [1.00000335], Accuracy = 0.5
# Epoch 47: Error = [1.00000331], Accuracy = 0.5
# Epoch 48: Error = [1.00000327], Accuracy = 0.5
# Epoch 49: Error = [1.00000323], Accuracy = 0.5
# Epoch 50: Error = [1.0000032], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[ 0.00281842 -0.00215947]
#  [ 0.00691425 -0.00908759]
#  [ 0.00228025  0.00053251]
#  [ 0.00041261 -0.00775938]]
# weights_hidden_output: [[ 0.00370156  0.00109247 -0.00780184 -0.00410219]]
# Squared Error at the end of training: [1.0000032]
# Accuracy at the end of training: 0.5
#
# Experiment 4:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00577182 -0.00938857]
#  [-0.00367974  0.00073542]
#  [-0.00136884 -0.00559702]
#  [-0.00903159  0.00165487]]
# weights_hidden_output: [[0.00186866 0.00630721 0.0070575  0.00836924]]
# Epoch 1: Error = [1.00003472], Accuracy = 0.5
# Epoch 2: Error = [1.00003431], Accuracy = 0.5
# Epoch 3: Error = [1.00003391], Accuracy = 0.5
# Epoch 4: Error = [1.00003351], Accuracy = 0.5
# Epoch 5: Error = [1.00003312], Accuracy = 0.5
# Epoch 6: Error = [1.00003274], Accuracy = 0.5
# Epoch 7: Error = [1.00003235], Accuracy = 0.5
# Epoch 8: Error = [1.00003198], Accuracy = 0.5
# Epoch 9: Error = [1.0000316], Accuracy = 0.5
# Epoch 10: Error = [1.00003123], Accuracy = 0.5
# Epoch 11: Error = [1.00003087], Accuracy = 0.5
# Epoch 12: Error = [1.00003051], Accuracy = 0.5
# Epoch 13: Error = [1.00003015], Accuracy = 0.5
# Epoch 14: Error = [1.0000298], Accuracy = 0.5
# Epoch 15: Error = [1.00002945], Accuracy = 0.5
# Epoch 16: Error = [1.00002911], Accuracy = 0.5
# Epoch 17: Error = [1.00002877], Accuracy = 0.5
# Epoch 18: Error = [1.00002843], Accuracy = 0.5
# Epoch 19: Error = [1.0000281], Accuracy = 0.5
# Epoch 20: Error = [1.00002777], Accuracy = 0.5
# Epoch 21: Error = [1.00002745], Accuracy = 0.5
# Epoch 22: Error = [1.00002713], Accuracy = 0.5
# Epoch 23: Error = [1.00002681], Accuracy = 0.5
# Epoch 24: Error = [1.0000265], Accuracy = 0.5
# Epoch 25: Error = [1.00002619], Accuracy = 0.5
# Epoch 26: Error = [1.00002588], Accuracy = 0.5
# Epoch 27: Error = [1.00002558], Accuracy = 0.5
# Epoch 28: Error = [1.00002528], Accuracy = 0.5
# Epoch 29: Error = [1.00002499], Accuracy = 0.5
# Epoch 30: Error = [1.00002469], Accuracy = 0.5
# Epoch 31: Error = [1.00002441], Accuracy = 0.5
# Epoch 32: Error = [1.00002412], Accuracy = 0.5
# Epoch 33: Error = [1.00002384], Accuracy = 0.5
# Epoch 34: Error = [1.00002356], Accuracy = 0.5
# Epoch 35: Error = [1.00002329], Accuracy = 0.5
# Epoch 36: Error = [1.00002301], Accuracy = 0.5
# Epoch 37: Error = [1.00002275], Accuracy = 0.5
# Epoch 38: Error = [1.00002248], Accuracy = 0.5
# Epoch 39: Error = [1.00002222], Accuracy = 0.5
# Epoch 40: Error = [1.00002196], Accuracy = 0.5
# Epoch 41: Error = [1.0000217], Accuracy = 0.5
# Epoch 42: Error = [1.00002145], Accuracy = 0.5
# Epoch 43: Error = [1.0000212], Accuracy = 0.5
# Epoch 44: Error = [1.00002095], Accuracy = 0.5
# Epoch 45: Error = [1.00002071], Accuracy = 0.5
# Epoch 46: Error = [1.00002046], Accuracy = 0.5
# Epoch 47: Error = [1.00002022], Accuracy = 0.5
# Epoch 48: Error = [1.00001999], Accuracy = 0.5
# Epoch 49: Error = [1.00001975], Accuracy = 0.5
# Epoch 50: Error = [1.00001952], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[ 0.00577003 -0.00939022]
#  [-0.00368807  0.00072686]
#  [-0.00137865 -0.00560661]
#  [-0.00904296  0.00164277]]
# weights_hidden_output: [[0.00036672 0.00480501 0.00555682 0.00686871]]
# Squared Error at the end of training: [1.00001952]
# Accuracy at the end of training: 0.5
#
# Experiment 5:
# Initial Random Weights:
# weights_input_hidden: [[ 0.00997342 -0.00651764]
#  [-0.00939411 -0.00232593]
#  [-0.00679088 -0.00605612]
#  [ 0.00357984  0.00856404]]
# weights_hidden_output: [[-0.00654589  0.00197161  0.00190837  0.00429872]]
# Epoch 1: Error = [1.00000017], Accuracy = 0.5
# Epoch 2: Error = [1.00000016], Accuracy = 0.5
# Epoch 3: Error = [1.00000016], Accuracy = 0.5
# Epoch 4: Error = [1.00000016], Accuracy = 0.5
# Epoch 5: Error = [1.00000016], Accuracy = 0.5
# Epoch 6: Error = [1.00000016], Accuracy = 0.5
# Epoch 7: Error = [1.00000015], Accuracy = 0.5
# Epoch 8: Error = [1.00000015], Accuracy = 0.5
# Epoch 9: Error = [1.00000015], Accuracy = 0.5
# Epoch 10: Error = [1.00000015], Accuracy = 0.5
# Epoch 11: Error = [1.00000015], Accuracy = 0.5
# Epoch 12: Error = [1.00000015], Accuracy = 0.5
# Epoch 13: Error = [1.00000014], Accuracy = 0.5
# Epoch 14: Error = [1.00000014], Accuracy = 0.5
# Epoch 15: Error = [1.00000014], Accuracy = 0.5
# Epoch 16: Error = [1.00000014], Accuracy = 0.5
# Epoch 17: Error = [1.00000014], Accuracy = 0.5
# Epoch 18: Error = [1.00000014], Accuracy = 0.5
# Epoch 19: Error = [1.00000013], Accuracy = 0.5
# Epoch 20: Error = [1.00000013], Accuracy = 0.5
# Epoch 21: Error = [1.00000013], Accuracy = 0.5
# Epoch 22: Error = [1.00000013], Accuracy = 0.5
# Epoch 23: Error = [1.00000013], Accuracy = 0.5
# Epoch 24: Error = [1.00000013], Accuracy = 0.5
# Epoch 25: Error = [1.00000012], Accuracy = 0.5
# Epoch 26: Error = [1.00000012], Accuracy = 0.5
# Epoch 27: Error = [1.00000012], Accuracy = 0.5
# Epoch 28: Error = [1.00000012], Accuracy = 0.5
# Epoch 29: Error = [1.00000012], Accuracy = 0.5
# Epoch 30: Error = [1.00000012], Accuracy = 0.5
# Epoch 31: Error = [1.00000012], Accuracy = 0.5
# Epoch 32: Error = [1.00000012], Accuracy = 0.5
# Epoch 33: Error = [1.00000011], Accuracy = 0.5
# Epoch 34: Error = [1.00000011], Accuracy = 0.5
# Epoch 35: Error = [1.00000011], Accuracy = 0.5
# Epoch 36: Error = [1.00000011], Accuracy = 0.5
# Epoch 37: Error = [1.00000011], Accuracy = 0.5
# Epoch 38: Error = [1.00000011], Accuracy = 0.5
# Epoch 39: Error = [1.00000011], Accuracy = 0.5
# Epoch 40: Error = [1.0000001], Accuracy = 0.5
# Epoch 41: Error = [1.0000001], Accuracy = 0.5
# Epoch 42: Error = [1.0000001], Accuracy = 0.5
# Epoch 43: Error = [1.0000001], Accuracy = 0.5
# Epoch 44: Error = [1.0000001], Accuracy = 0.5
# Epoch 45: Error = [1.0000001], Accuracy = 0.5
# Epoch 46: Error = [1.0000001], Accuracy = 0.5
# Epoch 47: Error = [1.0000001], Accuracy = 0.5
# Epoch 48: Error = [1.0000001], Accuracy = 0.5
# Epoch 49: Error = [1.00000009], Accuracy = 0.5
# Epoch 50: Error = [1.00000009], Accuracy = 0.5
# Final Weights:
# weights_input_hidden: [[ 0.00997448 -0.00651753]
#  [-0.00939435 -0.0023263 ]
#  [-0.00679117 -0.00605643]
#  [ 0.00357973  0.00856373]]
# weights_hidden_output: [[-0.00664987  0.00186802  0.0018048   0.00419452]]
# Squared Error at the end of training: [1.00000009]
# Accuracy at the end of training: 0.5
